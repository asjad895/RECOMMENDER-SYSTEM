# %%
import numpy as np
import pandas as pd

# %%
books=pd.read_csv('BX-CSV-Dump/BX-Books.csv',sep=';', error_bad_lines=False,encoding='latin-1')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15620\19590044.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books=pd.read_csv('BX-CSV-Dump/BX-Books.csv',sep=';', error_bad_lines=False,encoding='latin-1')
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# Skipping line 220626: expected 8 fields, saw 9
# Skipping line 227933: expected 8 fields, saw 11
# Skipping line 228957: expected 8 fields, saw 10
# Skipping line 245933: expected 8 fields, saw 9
# Skipping line 251296: expected 8 fields, saw 9
# Skipping line 259941: expected 8 fields, saw 9
# Skipping line 261529: expected 8 fields, saw 9
#
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15620\19590044.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('BX-CSV-Dump/BX-Books.csv',sep=';', error_bad_lines=False,encoding='latin-1')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
user=pd.read_csv('BX-CSV-Dump/BX-Users.csv',sep=';', error_bad_lines=False,encoding='latin-1')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15620\158773740.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   user=pd.read_csv('BX-CSV-Dump/BX-Users.csv',sep=';', error_bad_lines=False,encoding='latin-1')

# %%
rating=pd.read_csv('BX-CSV-Dump/BX-Book-Ratings.csv',sep=';', error_bad_lines=False,encoding='latin-1')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15620\2842084043.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rating=pd.read_csv('BX-CSV-Dump/BX-Book-Ratings.csv',sep=';', error_bad_lines=False,encoding='latin-1')

# %%
user
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
rating
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
rating=rating.rename(columns={'User-ID':'user_id','Book-Rating':'rating'})

# %%
books.shape,user.shape,rating.shape
# Out:
# ((271360, 8), (278858, 3), (1149780, 3))

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books=books[['ISBN', 'Book-Title', 'Book-Author','Year-Of-Publication', 'Publisher']]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
# [271360 rows x 5 columns]

# %%
books=books.rename(columns={'Book-Title':'title','Book-Author':'author','Year-Of-Publication':'year'})

# %%
books
# Out:
#               ISBN                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# 2               Carlo D'Este  1991
# 3           Gina Bari Kolata  1999
# 4            E. J. W. Barber  1999
# ...                      ...   ...
# 271355        Paula Danziger  1988
# 271356            Teri Sloat  1991
# 271357      Christine Wicker  2004
# 271358                 Plato  1996
# 271359   Christopher  Biffle  2000
#
#                                                Publisher
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
# [271360 rows x 5 columns]

# %%
user.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
user=user.rename(columns={'User-ID':'user_id', 'Location':'location', 'Age':'age'})

# %%
user
# Out:
#         user_id                            location   age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
rating['user_id'].value_counts().shape#rhere is only such users that gives rating
# Out:
# (105283,)

# %%
x=rating['user_id'].value_counts()>200#taking users which gives greater than 200 rating

# %%
y=x[x].index

# %%
rating=rating[rating['user_id'].isin(y)]

# %%
rating
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
rating_with_books=rating.merge(books,on='ISBN')

# %%
rating_with_books.shape
# Out:
# (487671, 7)

# %%
no_of_ratings=rating_with_books.groupby('title')['rating'].count().reset_index().rename(columns={'rating':'no_of_rating'})

# %%
no_of_ratings
# Out:
#                                                     title  no_of_rating
# 0        A Light in the Storm: The Civil War Diary of ...             2
# 1                                   Always Have Popsicles             1
# 2                    Apple Magic (The Collector's series)             1
# 3        Beyond IBM: Leadership Marketing and Finance ...             1
# 4        Clifford Visita El Hospital (Clifford El Gran...             1
# ...                                                   ...           ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...             3
# 160265                                      Ã?Â?lpiraten.             1
# 160266                     Ã?Â?rger mit Produkt X. Roman.             1
# 160267                              Ã?Â?stlich der Berge.             1
# 160268                                  Ã?Â?thique en toc             1
#
# [160269 rows x 2 columns]

# %%
final_rating=no_of_ratings.merge(rating_with_books,on='title')

# %%
final_rating
# Out:
#                                                     title  no_of_rating  \
# 0        A Light in the Storm: The Civil War Diary of ...             2
# 1        A Light in the Storm: The Civil War Diary of ...             2
# 2                                   Always Have Popsicles             1
# 3                    Apple Magic (The Collector's series)             1
# 4        Beyond IBM: Leadership Marketing and Finance ...             1
# ...                                                   ...           ...
# 487666  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...             3
# 487667                                      Ã?Â?lpiraten.             1
# 487668                     Ã?Â?rger mit Produkt X. Roman.             1
# 487669                              Ã?Â?stlich der Berge.             1
# 487670                                  Ã?Â?thique en toc             1
#
#         user_id        ISBN  rating                     author  year  \
# 0         35859  0590567330       0                Karen Hesse  1999
# 1         96448  0590567330       9                Karen Hesse  1999
# 2        172742  0964147726       0             Rebecca Harvin  1994
# 3        198711  0942320093       0           Martina Boudreau  1984
# 4         11601  0962295701       0                 Lou Mobley  1989
# ...         ...         ...     ...                        ...   ...
# 487666   173632  3257700512       0        Henry David Thoreau  1996
# 487667    11676  3499232499       0  Janwillem van de Wetering  2002
# 487668   133567  325721538X       8                 Joan Aiken  1987
# 487669   261105  3442725739       0             David Guterson  2000
# 487670    53628  2842192508       0           Didier Daeninckx  1998
#
#                           Publisher
# 0       Hyperion Books for Children
# 1       Hyperion Books for Children
# 2                 Rebecca L. Harvin
# 3                Amer Cooking Guild
# 4            Teleonet, Incorporated
# ...                             ...
# 487666                     Diogenes
# 487667                  Rowohlt Tb.
# 487668              Diogenes Verlag
# 487669                          btb
# 487670                      Baleine
#
# [487671 rows x 8 columns]

# %%
final_rating=final_rating[final_rating['no_of_rating']>50]

# %%
final_rating
# Out:
#                       title  no_of_rating  user_id        ISBN  rating  \
# 1073                   1984            76      254  0451524934       9
# 1074                   1984            76    11676  0451524934       0
# 1075                   1984            76    12538  0451524934       0
# 1076                   1984            76    15408  0451524934       9
# 1077                   1984            76    16795  0451524934       8
# ...                     ...           ...      ...         ...     ...
# 487432  \O\" Is for Outlaw"           105   234359  0805059555       0
# 487433  \O\" Is for Outlaw"           105   234623  0805059555       0
# 487434  \O\" Is for Outlaw"           105   236283  0805059555      10
# 487435  \O\" Is for Outlaw"           105   238120  0805059555       0
# 487436  \O\" Is for Outlaw"           105   254899  0805059555       0
#
#                author  year                 Publisher
# 1073    George Orwell  1990               Signet Book
# 1074    George Orwell  1990               Signet Book
# 1075    George Orwell  1990               Signet Book
# 1076    George Orwell  1990               Signet Book
# 1077    George Orwell  1990               Signet Book
# ...               ...   ...                       ...
# 487432    Sue Grafton  1999  Henry Holt &amp; Company
# 487433    Sue Grafton  1999  Henry Holt &amp; Company
# 487434    Sue Grafton  1999  Henry Holt &amp; Company
# 487435    Sue Grafton  1999  Henry Holt &amp; Company
# 487436    Sue Grafton  1999  Henry Holt &amp; Company
#
# [59903 rows x 8 columns]

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15620\1573401051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating
# Out:
#                       title  no_of_rating  user_id        ISBN  rating  \
# 1073                   1984            76      254  0451524934       9
# 1074                   1984            76    11676  0451524934       0
# 1075                   1984            76    12538  0451524934       0
# 1076                   1984            76    15408  0451524934       9
# 1077                   1984            76    16795  0451524934       8
# ...                     ...           ...      ...         ...     ...
# 487432  \O\" Is for Outlaw"           105   234359  0805059555       0
# 487433  \O\" Is for Outlaw"           105   234623  0805059555       0
# 487434  \O\" Is for Outlaw"           105   236283  0805059555      10
# 487435  \O\" Is for Outlaw"           105   238120  0805059555       0
# 487436  \O\" Is for Outlaw"           105   254899  0805059555       0
#
#                author  year                 Publisher
# 1073    George Orwell  1990               Signet Book
# 1074    George Orwell  1990               Signet Book
# 1075    George Orwell  1990               Signet Book
# 1076    George Orwell  1990               Signet Book
# 1077    George Orwell  1990               Signet Book
# ...               ...   ...                       ...
# 487432    Sue Grafton  1999  Henry Holt &amp; Company
# 487433    Sue Grafton  1999  Henry Holt &amp; Company
# 487434    Sue Grafton  1999  Henry Holt &amp; Company
# 487435    Sue Grafton  1999  Henry Holt &amp; Company
# 487436    Sue Grafton  1999  Henry Holt &amp; Company
#
# [57952 rows x 8 columns]

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             2977    3363    3757    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             4017    4385    6242    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     7.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# 4 Blondes                                              0.0  ...     NaN
# 84 Charing Cross Road                                  NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# user_id                                             274061  274301  274308  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     0.0
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     8.0     NaN
#
# user_id                                             274808  275970  277427  \
# title
# 1984                                                   NaN     0.0     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN    10.0     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     0.0     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             277478  277639  278418
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [703 rows x 888 columns]

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             2977    3363    3757    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             4017    4385    6242    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     7.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# 84 Charing Cross Road                                  0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user_id                                             274061  274301  274308  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# user_id                                             274808  275970  277427  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0    10.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             277478  277639  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [703 rows x 888 columns]

# %%
from scipy.sparse import csr_matrix
book_sparse=csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <703x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14507 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
nn_model=NearestNeighbors(algorithm='brute')

# %%
nn_model
# Out:
# NearestNeighbors(algorithm='brute')

# %%
nn_model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distances,suggestion=nn_model.kneighbors(book_pivot.iloc[507,:].values.reshape(1,-1),n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 13.7113092 , 19.39071943, 19.77371993, 20.73644135,
#         21.11871208]])

# %%
suggestion
# Out:
# array([[507, 173, 564, 175, 277, 356]], dtype=int64)

# %%
for i in range((len(suggestion))):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['The Cradle Will Fall', 'Exclusive', 'The Long Road Home',
#        'Eyes of a Child', 'Jacob Have I Loved', 'No Safe Place'],
#       dtype='object', name='title')

# %%
book_pivot.index[237]
# Out:
# 'Hemlock Bay'

# %%
book_pivot.index[507]
# Out:
# 'The Cradle Will Fall'

# %%
np.where(book_pivot.index=='Animal Farm')[0][0]
# Out:
# 47

# %%
def recommend(book):
    ind=np.where(book_pivot.index==book)[0][0]
    distances,suggestion=nn_model.kneighbors(book_pivot.iloc[ind,:].values.reshape(1,-1),n_neighbors=6)
    rec_book=[]
    for i in range((len(suggestion))):
        #rec_book.append(book_pivot.index[suggestion[i]])
        if i==0:
            print("The suggestion for book",book ,"are:")
        if not i:
            print(book_pivot.index[suggestion[i]])

# %%
recommend('Animal Farm')
# Out:
# The suggestion for book Animal Farm are:
# Index(['Animal Farm', 'Exclusive', 'Jacob Have I Loved', 'Pleading Guilty',
#        'No Safe Place', 'Foucault's Pendulum'],
#       dtype='object', name='title')

# %%
import pickle
pickle.dump(nn_model,open('nn_model.pkl','wb'))

# %%
pickle.dump(book_pivot,open('book_pivot.pkl','wb'))
